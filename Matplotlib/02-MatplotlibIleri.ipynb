# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
numpyDizisi1 = np.linspace(0,10,20)

# %%
numpyDizisi2 = numpyDizisi1 ** 2

# %%
(benimFigur, benimEksen) = plt.subplots()
benimEksen.plot(numpyDizisi1, numpyDizisi2, color="#3A95A8",alpha=0.3)
benimEksen.plot(numpyDizisi2,numpyDizisi1,color="#C96F23")

# %%
(yeniFigur, yeniEksen) = plt.subplots()
yeniEksen.plot(numpyDizisi1, numpyDizisi1 + 2, color="blue", linewidth = 1.0)#linewidth kalınlık ayarlar
yeniEksen.plot(numpyDizisi1, numpyDizisi1 + 3, color ="yellow", linewidth = 1.0)

yeniEksen.plot(numpyDizisi1, numpyDizisi1 + 4, color = "#C96F23", linestyle = "-.")#grafiğin çizgi mi nokta mı olacağına karar verir
yeniEksen.plot(numpyDizisi1, numpyDizisi1 + 5, color = "#C96F23", linestyle = ":")
yeniEksen.plot(numpyDizisi1, numpyDizisi1 + 6, color = "#C96F23", linestyle = "--")

yeniEksen.plot(numpyDizisi1, numpyDizisi1 + 7, color = "#000000", linestyle = "--", marker = "o",markersize = 8, markerfacecolor="red")
yeniEksen.plot(numpyDizisi1, numpyDizisi1 + 8, color = "#000000", linestyle = "--", marker = "+",markersize = 4)

# %% [markdown]
# scatter

# %%
plt.scatter(numpyDizisi1,numpyDizisi2)

# %% [markdown]
# histogram

# %%
yeniDizi = np.random.randint(0,100,50)

# %%
yeniDizi
# Out:
# array([ 1,  8, 35, 35, 85, 45, 22,  9, 71, 88, 56, 48, 76, 25, 81, 81, 45,
#        92,  5, 28,  4, 71, 35, 53, 44, 35, 62, 12, 96,  8, 87, 24, 63, 16,
#        73, 57, 16, 67, 81, 13, 43, 45,  3,  3, 26, 26, 83, 79, 26, 96])

# %%
plt.hist(yeniDizi)
# Out:
# (array([8., 4., 7., 4., 6., 3., 3., 4., 6., 5.]),
#  array([ 1. , 10.5, 20. , 29.5, 39. , 48.5, 58. , 67.5, 77. , 86.5, 96. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# boxplot

# %%
plt.boxplot(yeniDizi*2)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x183aea41970>,
#   <matplotlib.lines.Line2D at 0x183aea41c40>],
#  'caps': [<matplotlib.lines.Line2D at 0x183aea41f10>,
#   <matplotlib.lines.Line2D at 0x183aea51220>],
#  'boxes': [<matplotlib.lines.Line2D at 0x183aea416a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x183aea514f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x183aea51760>],
#  'means': []}
